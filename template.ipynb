# %% [markdown]
# <a href="https://colab.research.google.com/github/hanaAbdulrazek/NewRepo/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo for notebooks.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **[1] Data Overviewing**

# %% [markdown]
# ### 1.1) importing modules and reading Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import scipy.stats as stats
# %matplotlib inline

# %%
data=pd.read_csv("/content/predict price column.csv")

# %%
data.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  Individual  2393 cc
#
# ...

# %% [markdown]
# <font size='5'> **Data Description :** </font>
#
# *  **Make**: The manufacturer or brand of the vehicle.
# *  **Model**: The specific model or variant of the car.
# *  **Price**: The cost of the car in the respective currency.
# *  **Year**: The manufacturing year of the vehicle.
# *  **Kilometer:**The distance the car has traveled in kilometers.
# *  **Fuel Type:** The type of fuel the car uses (e.g., `petrol`, `diesel`).
# *  **Transmission:** The type of gearbox the car has (e.g., `manual`, `automatic`).
# *  **Location:** The place or city where the car is available or located.
# *  **Color:** The exterior color of the car.
# * **Owner:** Indicates the ownership status, such as `"First"` or `"Second"`.
# *  **Seller Type:** Specifies if the seller is an `individual` or `a corporate entity`.
# * **Engine:**The engine displacement in cubic centimeters (cc).
# *  **Max Power:** The maximum power the engine produces, typically in brake horsepower (bhp) and at what rpm.
# *  **Max Torque:** The maximum torque the engine generates, usually measured in Newton-meters (Nm) and at what rpm.
# *  **Drivetrain:** Specifies the type of drivetrain, like `front-wheel drive (FWD)` or `rear-wheel drive (RWD)`.
# *  **Length:** The length of the car in millimeters.
# * **Width:** The width of the car in millimeters.
# * **Height:** The height of the car in millimeters.
# *  **Seating Capacity:**The number of seats the car has.
# *  **Fuel Tank Capacity:** The volume of fuel the car's tank can hold, typically in liters.

# %% [markdown]
# - - -

# %% [markdown]
# Determining the dimensions of the dataset by retrieving the count of rows and columns.

# %%
data.shape
# Out:
# (2059, 20)

# %% [markdown]
# *  Our Training Dataset consists of `2059` rows and `20` columns.

# %% [markdown]
# Obtaining insightful information regarding the dataset's attributes and their characteristics.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   int64
#  3   Year                2059 non-null   int64
#  4   Kilometer           2059 non-null   int64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              1979 non-null   object
#  12  Max Power           1979 non-null   object
#  13  Max Torque          1979 non-null   object
#  14  Drivetrain          1923 non-null   object
# ...

# %% [markdown]
# **Observations:**
#
# *  There are 9 columns contains null values.
#
# *  The column that represent date `Year`  is currently stored as int datatype, suggesting the need for further conversion to datetime format.

# %% [markdown]
# Transforming the column into datetime format to enable flexible datetime manipulation.

# %%
data['Year'] = pd.to_datetime(data['Year'])

# %% [markdown]
# Verifying the data types again to confirm the successful conversion of datetime.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   int64
#  3   Year                2059 non-null   datetime64[ns]
#  4   Kilometer           2059 non-null   int64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              1979 non-null   object
#  12  Max Power           1979 non-null   object
#  13  Max Torque          1979 non-null   object
#  14  Drivetrain          1923 non-null   object
# ...

# %% [markdown]
# Generating descriptive statistics for numerical columns.

# %%
data.describe()
# Out:
#               Price                           Year     Kilometer       Length  \
# count  2.059000e+03                           2059  2.059000e+03  1995.000000
# mean   1.702992e+06  1970-01-01 00:00:00.000002016  5.422471e+04  4280.860652
# min    4.900000e+04  1970-01-01 00:00:00.000001988  0.000000e+00  3099.000000
# 25%    4.849990e+05  1970-01-01 00:00:00.000002014  2.900000e+04  3985.000000
# 50%    8.250000e+05  1970-01-01 00:00:00.000002017  5.000000e+04  4370.000000
# 75%    1.925000e+06  1970-01-01 00:00:00.000002019  7.200000e+04  4629.000000
# max    3.500000e+07  1970-01-01 00:00:00.000002022  2.000000e+06  5569.000000
# std    2.419881e+06                            NaN  5.736172e+04   442.458507
#
#              Width       Height  Seating Capacity  Fuel Tank Capacity
# count  1995.000000  1995.000000       1995.000000         1946.000000
# mean   1767.991980  1591.735338          5.306266           52.002210
# ...

# %% [markdown]
# Generating descriptive statistics for categorical columns.

# %%
data.describe(include='object').T
# Out:
#              count unique                 top  freq
# Make          2059     33       Maruti Suzuki   440
# Model         2059   1050  X1 sDrive20d xLine    15
# Fuel Type     2059      9              Diesel  1049
# Transmission  2059      2              Manual  1133
# Location      2059     77              Mumbai   342
# Color         2059     17               White   802
# Owner         2059      6               First  1619
# Seller Type   2059      3          Individual  1997
# Engine        1979    108             1197 cc   231
# Max Power     1979    335   89 bhp @ 4000 rpm    90
# Max Torque    1979    290   200 Nm @ 1750 rpm    90
# Drivetrain    1923      3                 FWD  1330

# %% [markdown]
# **Observations:**
#
#
#
# *   The Most Repeated car is Maruti Suzuki
# *   The Most Repeated color is white.
# *   The Most Repeated Transmisiion type is Manual.

# %% [markdown]
# - - -

# %% [markdown]
# ### 1.2) Exploratory Data Analysis

# %%
data.head()
# Out:
#             Make                            Model    Price  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000
# 1  Maruti Suzuki                  Swift DZire VDI   450000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000
# 3         Toyota                         Glanza G   799000
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000
#
#                            Year  Kilometer Fuel Type Transmission   Location  \
# 0 1970-01-01 00:00:00.000002017      87150    Petrol       Manual       Pune
# 1 1970-01-01 00:00:00.000002014      75000    Diesel       Manual   Ludhiana
# 2 1970-01-01 00:00:00.000002011      67000    Petrol       Manual    Lucknow
# 3 1970-01-01 00:00:00.000002019      37500    Petrol       Manual  Mangalore
# 4 1970-01-01 00:00:00.000002018      69000    Diesel       Manual     Mumbai
#
#     Color   Owner Seller Type   Engine           Max Power  \
# 0    Grey   First   Corporate  1198 cc   87 bhp @ 6000 rpm
# ...

# %% [markdown]
# Displaying the count of unique `Brands` present within the dataset.

# %%
data['Make'].nunique()
# Out:
# 33

# %% [markdown]
# Displaying the occurrence for each Brand.

# %%
data['Make'].value_counts()
# Out:
# Make
# Maruti Suzuki    440
# Hyundai          349
# Mercedes-Benz    171
# Honda            158
# Toyota           132
# Audi             127
# BMW              121
# Mahindra         119
# Tata              57
# Volkswagen        50
# Ford              48
# Renault           43
# Skoda             40
# Land Rover        33
# Kia               23
# Jeep              18
# Jaguar            17
# MG                17
# Nissan            16
# Volvo             16
# Porsche           15
# MINI              11
# Datsun             8
# Chevrolet          7
# Lexus              6
# Mitsubishi         4
# Ssangyong          3
# Rolls-Royce        3
# Isuzu              2
# Fiat               2
# Maserati           1
# Ferrari            1
# Lamborghini        1
# Name: count, dtype: int64

# %% [markdown]
# Applying The same thing to the whole data.

# %%
data['Model'].value_counts()
# Out:
# Model
# X1 sDrive20d xLine                 15
# Swift DZire VDI                    14
# City V                             13
# Fortuner 2.8 4x2 AT [2016-2020]    13
# Swift DZire VXI                    12
#                                    ..
# XF R 5.0 V8 Supercharged            1
# Pajero SFX 2.8                      1
# Etios G                             1
# Marazzo M6 Plus 8 STR               1
# Figo Duratec Petrol ZXI 1.2         1
# Name: count, Length: 1050, dtype: int64

# %%
data['Fuel Type'].value_counts()
# Out:
# Fuel Type
# Diesel          1049
# Petrol           942
# CNG               50
# Electric           7
# LPG                5
# Hybrid             3
# CNG + CNG          1
# Petrol + CNG       1
# Petrol + LPG       1
# Name: count, dtype: int64

# %%
data['Transmission'].value_counts()
# Out:
# Transmission
# Manual       1133
# Automatic     926
# Name: count, dtype: int64

# %%
data['Location'].value_counts()
# Out:
# Location
# Mumbai              342
# Delhi               307
# Pune                144
# Bangalore           132
# Hyderabad           116
#                    ...
# Faizabad              1
# Pimpri-Chinchwad      1
# Rohtak                1
# Valsad                1
# Siliguri              1
# Name: count, Length: 77, dtype: int64

# %%
data['Color'].value_counts()
# Out:
# Color
# White     802
# Silver    285
# Grey      220
# Blue      190
# Black     163
# Red       154
# Brown      82
# Maroon     37
# Gold       30
# Bronze     28
# Green      17
# Orange     16
# Others     12
# Yellow      9
# Beige       8
# Purple      5
# Pink        1
# Name: count, dtype: int64

# %%
data['Owner'].value_counts()
# Out:
# Owner
# First               1619
# Second               373
# Third                 42
# UnRegistered Car      21
# Fourth                 3
# 4 or More              1
# Name: count, dtype: int64

# %%
data['Seller Type'].value_counts()
# Out:
# Seller Type
# Individual                 1997
# Corporate                    57
# Commercial Registration       5
# Name: count, dtype: int64

# %%
data['Engine'].value_counts()
# Out:
# Engine
# 1197 cc    231
# 1248 cc    122
# 998 cc     121
# 1497 cc     84
# 1968 cc     82
#           ...
# 1948 cc      1
# 4806 cc      1
# 3496 cc      1
# 2609 cc      1
# 995 cc       1
# Name: count, Length: 108, dtype: int64

# %%
data['Max Torque'].value_counts()
# Out:
# Max Torque
# 200 Nm @ 1750 rpm    90
# 115 Nm @ 4000 rpm    78
# 114 Nm @ 4000 rpm    66
# 90 Nm @ 3500 rpm     64
# 400 Nm @ 1750 rpm    63
#                      ..
# 505 Nm @ 4400 rpm     1
# 290@1800              1
# 380 Nm @ 2500 rpm     1
# 560 Nm @ 6500 rpm     1
# 480 Nm @ 1600 rpm     1
# Name: count, Length: 290, dtype: int64

# %%
data['Drivetrain'].value_counts()
# Out:
# Drivetrain
# FWD    1330
# RWD     321
# AWD     272
# Name: count, dtype: int64

# %%
data['Seating Capacity'].value_counts()
# Out:
# Seating Capacity
# 5.0    1615
# 7.0     273
# 4.0      42
# 8.0      35
# 6.0      23
# 2.0       7
# Name: count, dtype: int64

# %%
data['Fuel Tank Capacity'].value_counts()
# Out:
# Fuel Tank Capacity
# 35.0     222
# 60.0     155
# 45.0     154
# 43.0     146
# 50.0     132
# 55.0     117
# 42.0     111
# 40.0     106
# 80.0      92
# 37.0      89
# 66.0      59
# 70.0      59
# 65.0      55
# 48.0      51
# 57.0      44
# 64.0      31
# 28.0      30
# 63.0      30
# 75.0      30
# 32.0      27
# 52.0      20
# 44.0      20
# 93.0      18
# 100.0     15
# 54.0      14
# 67.0      12
# 56.0      11
# 90.0      10
# 78.0       7
# 51.0       6
# 83.0       6
# 41.0       6
# 27.0       5
# 77.0       5
# 85.0       5
# 62.0       5
# 71.0       5
# 82.0       4
# 105.0      3
# 82.5       3
# 58.0       3
# 47.0       3
# 68.0       3
# 59.0       3
# 95.0       2
# 73.0       2
# 60.9       2
# 15.0       1
# 66.5       1
# 104.0      1
# 92.0       1
# 67.5       1
# 81.0       1
# 61.0       1
# 38.0       1
# Name: count, dtype: int64

# %% [markdown]
# The Values Seems To Be `Normal`.

# %% [markdown]
# - - -

# %% [markdown]
# Number of `Models` For Each Car Brand

# %%
brand_models_count = data.groupby('Make')['Model'].nunique().sort_values(ascending=False)

plt.figure(figsize=(8, 6))
brand_models_count.plot(kind='bar', color='skyblue')
plt.title('Number of Car Models for Each Brand')
plt.xlabel('Brand')
plt.ylabel('Number of Models')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# *   Suzuki and Hyundai have the highest number of Models.
# *   Ferrari have very few Models.

# %% [markdown]
# Calculate The Average Mileage for each Brand.

# %%
df = pd.DataFrame(data)

avg_mileage_by_brand = df.groupby('Make')['Kilometer'].mean().sort_values()

plt.figure(figsize=(10, 6))
avg_mileage_by_brand.plot(kind='bar', color='skyblue',width=0.75)
plt.title('Average Mileage by Car Brand')
plt.xlabel('Car Brand')
plt.ylabel('Average Mileage')
plt.xticks(rotation=43)
plt.tight_layout()

plt.show()

# %% [markdown]
# **Observation:**
#
# *  Lamborghini has the `Least` Average Mileage as it is considered as a SuperCar and not made for daily driving.
#
# *   Renault has the `Highest` Average Mileage which gives as an indication that the car is economical.

# %% [markdown]
# Car Brands Distribution in the Most Frequent Locations.

# %%
top_locations = df['Location'].value_counts().nlargest(5).index

# Filter the DataFrame for the top locations
filtered_df = df[df['Location'].isin(top_locations)]

# Count the occurrences of each brand in each location
brand_location_counts = filtered_df.groupby(['Location', 'Make']).size().unstack().fillna(0)

plt.figure(figsize=(10, 6))
brand_location_counts.plot(kind='barh', stacked=True, colormap='tab20')

plt.title('Car Brands Distribution in Top Locations')
plt.xlabel('Counts')
plt.ylabel('Location')
plt.legend(title='Car Brands', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# *  Mumbai has the highest number of cars and Volkswagen has the highest number there.

# %% [markdown]
# Viewing if the Owner affects the Resale of the cars.

# %%
# Plotting box plot to visualize the relationship between owners and price
plt.figure(figsize=(8, 6))
plt.boxplot([df[df['Owner'] == i]['Price'] for i in df['Owner'].unique()],
            labels=df['Owner'].unique())
plt.title('Car Price Distribution by Number of Owners')
plt.xlabel('Number of Owners')
plt.ylabel('Price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# The Average Price for each combination of Owner and Seller Type

# %%
avg_prices = df.groupby(['Owner', 'Seller Type'])['Price'].mean().reset_index()

# Pivot the data for visualization
pivot_prices = avg_prices.pivot(index='Owner', columns='Seller Type', values='Price')

# Plotting the grouped bar plot
pivot_prices.plot(kind='bar', figsize=(10, 6))
plt.title('Average Price by Ownership and Seller Type')
plt.xlabel('Ownership')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.legend(title='Seller Type')

plt.tight_layout()
plt.show()

# %% [markdown]
# Average Price for each Fuel Type

# %%
# Calculate average price for Petrol and Diesel cars
average_price_by_fuel_type = df.groupby('Fuel Type')['Price'].mean()

# Plotting the bar plot for average prices by fuel type
plt.figure(figsize=(8, 6))
average_price_by_fuel_type.plot(kind='bar', color=['skyblue', 'lightgreen'])
plt.title('Average Price Comparison to Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# *   Hybrid Systems has the Highest Average Price.

# %% [markdown]
# Average Price for the most Frequent Cars over the years

# %%
car_frequency = df['Make'].value_counts()

top_n_cars = car_frequency.nlargest(8).index

df_filtered = df[df['Make'].isin(top_n_cars)]

# Calculate average price by year and brand/type for the most frequent cars
average_price_by_year_make = df_filtered.groupby(['Year', 'Make'])['Price'].mean().unstack()

# Plotting the average price trend over years for the most frequent cars
plt.figure(figsize=(10, 6))
for make in average_price_by_year_make.columns:
    plt.plot(average_price_by_year_make.index, average_price_by_year_make[make], marker='o', label=make)

plt.title('Average Price Trend over Years for Most Frequent Brands Types')
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# *   Mercedes-Benz have the `highest growthing rate` over the years
# *   Suzuki , Honda , Hyundai & Mahindra have `normal growthing rate` , so small in comparison to the other brands.

# %% [markdown]
# - - -

# %% [markdown]
# # **[2] Preprocessing**

# %%
data.head()
# Out:
#             Make                            Model    Price  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000
# 1  Maruti Suzuki                  Swift DZire VDI   450000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000
# 3         Toyota                         Glanza G   799000
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000
#
#                            Year  Kilometer Fuel Type Transmission   Location  \
# 0 1970-01-01 00:00:00.000002017      87150    Petrol       Manual       Pune
# 1 1970-01-01 00:00:00.000002014      75000    Diesel       Manual   Ludhiana
# 2 1970-01-01 00:00:00.000002011      67000    Petrol       Manual    Lucknow
# 3 1970-01-01 00:00:00.000002019      37500    Petrol       Manual  Mangalore
# 4 1970-01-01 00:00:00.000002018      69000    Diesel       Manual     Mumbai
#
#     Color   Owner Seller Type   Engine           Max Power  \
# 0    Grey   First   Corporate  1198 cc   87 bhp @ 6000 rpm
# ...

# %% [markdown]
# ### 2.1) Missing Values

# %% [markdown]
# Checking each column in our data for null values and counting their occurrences.

# %%
data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Price                   0
# Year                    0
# Kilometer               0
# Fuel Type               0
# Transmission            0
# Location                0
# Color                   0
# Owner                   0
# Seller Type             0
# Engine                 80
# Max Power              80
# Max Torque             80
# Drivetrain            136
# Length                 64
# Width                  64
# Height                 64
# Seating Capacity       64
# Fuel Tank Capacity    113
# dtype: int64

# %% [markdown]
# *   We've identified that we have `9 columns` contains nulls , columns `Drivetrain` and `Fuel Tank Capacity` , contains the highest number of null values.

# %% [markdown]
# Before proceeding to handle them, let's determine the proportion they represent within our dataset.

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# Make                  0.000000
# Model                 0.000000
# Price                 0.000000
# Year                  0.000000
# Kilometer             0.000000
# Fuel Type             0.000000
# Transmission          0.000000
# Location              0.000000
# Color                 0.000000
# Owner                 0.000000
# Seller Type           0.000000
# Engine                3.885381
# Max Power             3.885381
# Max Torque            3.885381
# Drivetrain            6.605148
# Length                3.108305
# Width                 3.108305
# Height                3.108305
# Seating Capacity      3.108305
# Fuel Tank Capacity    5.488101
# dtype: float64

# %% [markdown]
# *   As most of columns are categorical and we can get the null values from other rows that contains the same car model we will use `ffill` and `bfill` methods.

# %% [markdown]
# Taking a row as a sample to check for correctness.

# %%
rrow = data[data['Model'] == 'CR-V 2.4 AT']

print(rrow)
# Out:
#        Make        Model   Price                          Year  Kilometer  \
# 33    Honda  CR-V 2.4 AT  860000 1970-01-01 00:00:00.000002013      67000
# 164   Honda  CR-V 2.4 AT  250000 1970-01-01 00:00:00.000002006     119300
# 1527  Honda  CR-V 2.4 AT  844999 1970-01-01 00:00:00.000002014      80121
#
#      Fuel Type Transmission Location  Color   Owner Seller Type   Engine  \
# 33      Petrol    Automatic   Mumbai  Brown   First  Individual      NaN
# 164     Petrol    Automatic     Pune  Black   Third  Individual  2354 cc
# 1527    Petrol    Automatic   Mumbai  White  Second  Individual      NaN
#
#      Max Power Max Torque Drivetrain  Length   Width  Height  \
# 33         NaN        NaN        NaN     NaN     NaN     NaN
# 164   152@6000   215@3600        AWD  4630.0  1780.0  1710.0
# 1527       NaN        NaN        NaN     NaN     NaN     NaN
#
#       Seating Capacity  Fuel Tank Capacity
# 33                 NaN                 NaN
# ...

# %% [markdown]
# Applying the method in order to fill the null values.

# %%
car_data_filled = data.groupby('Model').apply(lambda x: x.ffill().bfill())

# Reset the index to match the original DataFrame
car_data_filled = car_data_filled.reset_index(drop=True)

print(car_data_filled)

data.update(car_data_filled)
# Out:
#          Make                                         Model    Price  \
# 0         BMW  2 Series Gran Coupe 220d M Sport [2020-2021]  4300000
# 1         BMW  2 Series Gran Coupe 220d M Sport [2020-2021]  4100000
# 2         BMW                                 3-Series 320d   800000
# 3         BMW                  3-Series 320d Highline Sedan  1200000
# 4         BMW                  3-Series 320d Luxury Edition  4550000
# ...       ...                                           ...      ...
# 2054  Hyundai                            i20 Sportz 1.2 (O)   275000
# 2055  Hyundai                          i20 Sportz 1.2 BS-IV   350000
# 2056  Hyundai                           i20 Sportz 1.4 CRDI   360000
# 2057  Hyundai                           i20 Sportz 1.4 CRDI   550000
# 2058  Hyundai                           i20 Sportz 1.4 CRDI   409999
#
#                               Year  Kilometer Fuel Type Transmission  \
# ...

# %% [markdown]
# Ckecking for correctness in the `ffill` and `bfill` Methods.

# %%
rrow = data[data['Model'] == 'CR-V 2.4 AT']

print(rrow)
# Out:
#       Make        Model   Price                          Year  Kilometer  \
# 346  Honda  CR-V 2.4 AT  860000 1970-01-01 00:00:00.000002013      67000
# 347  Honda  CR-V 2.4 AT  250000 1970-01-01 00:00:00.000002006     119300
# 348  Honda  CR-V 2.4 AT  844999 1970-01-01 00:00:00.000002014      80121
#
#     Fuel Type Transmission Location  Color   Owner Seller Type   Engine  \
# 346    Petrol    Automatic   Mumbai  Brown   First  Individual  2354 cc
# 347    Petrol    Automatic     Pune  Black   Third  Individual  2354 cc
# 348    Petrol    Automatic   Mumbai  White  Second  Individual  2354 cc
#
#     Max Power Max Torque Drivetrain  Length   Width  Height  Seating Capacity  \
# 346  152@6000   215@3600        AWD  4630.0  1780.0  1710.0               5.0
# 347  152@6000   215@3600        AWD  4630.0  1780.0  1710.0               5.0
# 348  152@6000   215@3600        AWD  4630.0  1780.0  1710.0               5.0
#
#      Fuel Tank Capacity
# 346                58.0
# ...

# %% [markdown]
# Checking the propotion again in our dataset.

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# Make                  0.000000
# Model                 0.000000
# Price                 0.000000
# Year                  0.000000
# Kilometer             0.000000
# Fuel Type             0.000000
# Transmission          0.000000
# Location              0.000000
# Color                 0.000000
# Owner                 0.000000
# Seller Type           0.000000
# Engine                0.097135
# Max Power             0.097135
# Max Torque            0.097135
# Drivetrain            0.388538
# Length                0.097135
# Width                 0.097135
# Height                0.097135
# Seating Capacity      0.097135
# Fuel Tank Capacity    0.291404
# dtype: float64

# %% [markdown]
# *   The Nulls percentage decreased but still exists so let's dive into other techniques.

# %% [markdown]
# Check the distribution of data in each column

# %%
# List of columns with null values
null_columns = df.columns[df.isnull().any()].tolist()



# Check if there are any null columns
if not null_columns:
    print("No columns with null values found.")

else:
# Calculate number of rows needed for subplots
 num_rows = len(null_columns) // 3 + (len(null_columns) % 3 > 0)

# Setting up subplots for each column
 fig, axes = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, 5*num_rows))

# Plotting distplots for columns with null values
 for i, col in enumerate(null_columns):
    row = i // 3
    col = i % 3
    sns.histplot(df[null_columns[i]].dropna(), kde=True, ax=axes[row, col])
    axes[row, col].set_title(f'Distribution of {null_columns[i]}')
    axes[row, col].set_xlabel(null_columns[i])
    axes[row, col].set_ylabel('Frequency')

 plt.tight_layout()
 plt.show()

# %% [markdown]
# All the columns are categorical so we will replace the null values with the mode.

# %%
data['Fuel Tank Capacity'].fillna(data['Fuel Tank Capacity'].mode()[0], inplace=True)
data['Seating Capacity'].fillna(data['Seating Capacity'].mode()[0], inplace=True)
data['Max Power'].fillna(data['Max Power'].mode()[0], inplace=True)
data['Max Torque'].fillna(data['Max Torque'].mode()[0], inplace=True)
data['Engine'].fillna(data['Engine'].mode()[0], inplace=True)
data['Height'].fillna(data['Height'].mode()[0], inplace=True)
data['Width'].fillna(data['Width'].mode()[0], inplace=True)
data['Length'].fillna(data['Length'].mode()[0], inplace=True)
data['Drivetrain'].fillna(data['Drivetrain'].mode()[0], inplace=True)

# %%
# List of columns after filling NaN values with mode
columns_after = [
    'Fuel Tank Capacity', 'Seating Capacity', 'Max Power', 'Max Torque',
    'Engine', 'Height', 'Width', 'Length', 'Drivetrain'
]
# Calculate the number of subplots needed
num_plots = len(columns_after) // 3 + (len(columns_after) % 3 > 0)

# Create subplots
fig, axes = plt.subplots(num_plots, 3, figsize=(15, 5*num_plots))

# Plotting displots for each set of three columns in 'columns_after'
for i, column_set in enumerate(zip(*[iter(columns_after)] * 3)):
    for j, col in enumerate(column_set):
        sns.histplot(data[col], kde=True, ax=axes[i, j])
        axes[i, j].set_title(f'{col} - After Mode Replacement')
        axes[i, j].set_xlabel(col)
        axes[i, j].set_ylabel('Frequency')

# If there are any remaining empty subplots, remove them
if len(columns_after) % 3 != 0:
    for k in range(len(columns_after) % 3, 3):
        fig.delaxes(axes[num_plots - 1, k])

plt.tight_layout()
plt.show()

# %% [markdown]
# Making Sure That we have Replaced all the Null values

# %%
df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Price                 0
# Year                  0
# Kilometer             0
# Fuel Type             0
# Transmission          0
# Location              0
# Color                 0
# Owner                 0
# Seller Type           0
# Engine                0
# Max Power             0
# Max Torque            0
# Drivetrain            0
# Length                0
# Width                 0
# Height                0
# Seating Capacity      0
# Fuel Tank Capacity    0
# dtype: int64

# %% [markdown]
# - - -

# %% [markdown]
# ### 2.2)Duplicates

# %% [markdown]
# Verifying the dataset to identify any duplicated rows that might be present.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no duplicate rows have been detected.

# %% [markdown]
# - - -

# %% [markdown]
# ### 2.3)Outliers.

# %% [markdown]
# Examining the numerical columns for the presence of outliers.

# %%
numerical_columns = data.select_dtypes(exclude=['object', 'datetime64[ns]']).columns


num_cols = len(numerical_columns)
num_rows = (num_cols + 1) // 2

plt.figure(figsize=(12, 6))


custom_colors = ['skyblue', 'salmon', 'lightgreen', 'skyblue', 'lightblue']

for i, col in enumerate(numerical_columns, 1):
    plt.subplot(num_rows, 2, i)
    sns.boxplot(x=data[col], color=custom_colors[i % len(custom_colors)])
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)

plt.tight_layout()
plt.show()

# %%
numerical_columns = data.select_dtypes(exclude=['object', 'datetime64[ns]']).columns

num_cols = len(numerical_columns)
num_rows = (num_cols + 1) // 2

plt.figure(figsize=(12, 12))

custom_colors = ['skyblue', 'salmon', 'lightgreen', 'skyblue', 'lightblue']

for i, col in enumerate(numerical_columns, 1):
    plt.subplot(num_rows, 2, i)
    sns.histplot(data[col], kde=True, color=custom_colors[i % len(custom_colors)])
    plt.title(f'Distribution with KDE of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
from scipy.stats import zscore

z_scores = df.select_dtypes(include='number').apply(zscore)

outlier_columns = z_scores.columns[(z_scores.abs() > 3).any()].tolist()

transformation_functions = {
    'Log Transformation': np.log1p,
    'Square Root Transformation': np.sqrt,
    'Cube Root Transformation': np.cbrt
}

for col in outlier_columns:
    plt.figure(figsize=(15, 5))
    for i, (transformation_name, transformation_func) in enumerate(transformation_functions.items(), 1):
        transformed_data = df[col].apply(transformation_func)
        plt.subplot(1, 3, i)
        sns.histplot(x=transformed_data, kde=True)
        plt.title(transformation_name)
        plt.xlabel(f'{transformation_name} {col}')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Observation :**
#
#
# *   Price Column : Log is the best way to reduce skewness.
# *   Kilometer Column : Cubic Root
# *  Width Column : Log Method
# *  Height column: Cubic Root
# *  Fuel Tank Capacity : Square Root
# ** we will leave `Seating capacity` as it is not solved by this methods.

# %%
data['Price'] = np.log1p(data['Price'])
data['Kilometer'] = np.cbrt(data['Kilometer'])
data['Width'] = np.log1p(data['Width'])
data['Height'] = np.cbrt(data['Height'])
data['Fuel Tank Capacity'] = np.sqrt(data['Fuel Tank Capacity'])
sns.boxplot(x = (data['Price']))
plt.show()

# %%
sns.boxplot(x = (data['Kilometer']))
plt.show()

# %%
sns.boxplot(x = (data['Width']))
plt.show()

# %%
sns.boxplot(x = (data['Height']))
plt.show()

# %%
sns.boxplot(x = (data['Fuel Tank Capacity']))
plt.show()

# %%
sns.boxplot(x = (data['Seating Capacity']))
plt.show()

# %%
numerical_columns = data.select_dtypes(exclude=['object', 'datetime64[ns]']).columns

num_cols = len(numerical_columns)
num_rows = (num_cols + 1) // 2

plt.figure(figsize=(12, 12))

custom_colors = ['skyblue', 'salmon', 'lightgreen', 'skyblue', 'lightblue']

for i, col in enumerate(numerical_columns, 1):
    plt.subplot(num_rows, 2, i)
    sns.histplot(data[col], kde=True, color=custom_colors[i % len(custom_colors)])
    plt.title(f'Distribution with KDE of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Let's compute the count and percentage of these outliers using the IQR method.

# %%
def calculate_outliers(col):
    sorted(col)
    Q1, Q3 = col.quantile([0.25, 0.75])
    IQR = Q3 - Q1
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range, upper_range

# %%
lower_limit, upper_limit = calculate_outliers((data['Seating Capacity']))

lower_outliers=len(data[(data['Seating Capacity'])<lower_limit])
upper_outliers=len(data[(data['Seating Capacity'])>upper_limit])

print(f"total outliers in col Seating Capacity  = ",upper_outliers+lower_outliers," with precentage of ",(upper_outliers+lower_outliers)/data.shape[0]*100)
# Out:
# total outliers in col Seating Capacity  =  388  with precentage of  18.84409907722195

# %% [markdown]
# - - -

# %% [markdown]
# ### 2.4) Encoding

# %%
data.head()
# Out:
#   Make                                         Model      Price  \
# 0  BMW  2 Series Gran Coupe 220d M Sport [2020-2021]  15.274126
# 1  BMW  2 Series Gran Coupe 220d M Sport [2020-2021]  15.226498
# 2  BMW                                 3-Series 320d  13.592368
# 3  BMW                  3-Series 320d Highline Sedan  13.997833
# 4  BMW                  3-Series 320d Luxury Edition  15.330638
#
#                            Year  Kilometer Fuel Type Transmission   Location  \
# 0 1970-01-01 00:00:00.000002020  22.239801    Diesel    Automatic       Pune
# 1 1970-01-01 00:00:00.000002020  22.980450    Diesel    Automatic  Hyderabad
# 2 1970-01-01 00:00:00.000002012  42.279317    Diesel    Automatic     Mumbai
# 3 1970-01-01 00:00:00.000002012  50.000000    Diesel    Automatic  Ahmedabad
# 4 1970-01-01 00:00:00.000002021  28.844991    Diesel    Automatic      Delhi
#
#    Color   Owner Seller Type   Engine           Max Power  \
# ...

# %%
data['Price'].nunique()
# Out:
# 619

# %% [markdown]
# Importing the Label Encoder module from Scikit-learn for encoding categorical data.

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %% [markdown]
# Applying Label Encoder to convert the categorical columns into numerical representations.
#
# *   Due to the large number of distinct categories and the absence of inherent order in these columns, Label Encoding is deemed the most suitable method for encoding nominal data.

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Price', 'Year', 'Kilometer', 'Fuel Type',
#        'Transmission', 'Location', 'Color', 'Owner', 'Seller Type', 'Engine',
#        'Max Power', 'Max Torque', 'Drivetrain', 'Length', 'Width', 'Height',
#        'Seating Capacity', 'Fuel Tank Capacity'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   float64
#  3   Year                2059 non-null   datetime64[ns]
#  4   Kilometer           2059 non-null   float64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              2059 non-null   object
#  12  Max Power           2059 non-null   object
#  13  Max Torque          2059 non-null   object
#  14  Drivetrain          2059 non-null   object
# ...

# %%
data['Make']=encoder.fit_transform(data['Make'])
data['Model']=encoder.fit_transform(data['Model'])
data['Year']=encoder.fit_transform(data['Year'])
data['Fuel Type']=encoder.fit_transform(data['Fuel Type'])
data['Transmission']=encoder.fit_transform(data['Transmission'])
data['Location']=encoder.fit_transform(data['Location'])
data['Color']=encoder.fit_transform(data['Color'])
data['Owner']=encoder.fit_transform(data['Owner'])
data['Seller Type']=encoder.fit_transform(data['Seller Type'])
data['Drivetrain']=encoder.fit_transform(data['Drivetrain'])
data['Engine']=encoder.fit_transform(data['Engine'])
data['Max Power']=encoder.fit_transform(data['Max Power'])
data['Max Torque']=encoder.fit_transform(data['Max Torque'])

# %%
data.head()
# Out:
#    Make  Model      Price  Year  Kilometer  Fuel Type  Transmission  Location  \
# 0     1      0  15.274126    19  22.239801          2             0        56
# 1     1      0  15.226498    19  22.980450          2             0        27
# 2     1      1  13.592368    11  42.279317          2             0        45
# 3     1      2  13.997833    11  50.000000          2             0         1
# 4     1      3  15.330638    20  28.844991          2             0        15
#
#    Color  Owner  Seller Type  Engine  Max Power  Max Torque  Drivetrain  \
# 0      2      1            2      47        144         199           1
# 1      2      1            1      47        144         199           1
# 2     15      3            2       6        301          11           1
# 3     15      1            2       6        305          15           1
# 4     15      1            2      47        144         199           2
#
# ...

# %%
datatypes = data.dtypes['Year']
print(datatypes)
# Out:
# int64

# %%
data.head()
# Out:
#    Make  Model      Price  Year  Kilometer  Fuel Type  Transmission  Location  \
# 0     1      0  15.274126    19  22.239801          2             0        56
# 1     1      0  15.226498    19  22.980450          2             0        27
# 2     1      1  13.592368    11  42.279317          2             0        45
# 3     1      2  13.997833    11  50.000000          2             0         1
# 4     1      3  15.330638    20  28.844991          2             0        15
#
#    Color  Owner  Seller Type  Engine  Max Power  Max Torque  Drivetrain  \
# 0      2      1            2      47        144         199           1
# 1      2      1            1      47        144         199           1
# 2     15      3            2       6        301          11           1
# 3     15      1            2       6        305          15           1
# 4     15      1            2      47        144         199           2
#
# ...

# %% [markdown]
# - - -

# %% [markdown]
# ### 2.5) Feature selection.

# %% [markdown]
# Analyzing the correlation between features to understand the relationships among the columns.

# %%
plt.figure(figsize=(17,15))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# According to the Correlation Heatmap above:
#
#
# *   There are many columns correlated to each other

# %% [markdown]
# To further validate feature selection, we'll specifically analyze the correlation values of all columns with the target variable, `Price`.

# %% [markdown]
# Determining the corerelation between features and the target variable to evaluate their suitability for model inclusion.

# %%
correlations = data.corr()['Price'].drop('Price')
sorted_correlations = correlations.sort_values(ascending=False)

plt.figure(figsize=(10, 6))
ax = sorted_correlations.plot(kind='bar', color='skyblue')
plt.title("Correlation with 'Price Column'")
plt.xlabel('Features')
plt.ylabel('Correlation')

for i, v in enumerate(sorted_correlations):
    ax.text(i, v + 0.001, f'{v:.2f}', ha='center', va='bottom')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# *  We will take the highly correlated columns which are (Max Power,Length,Fuel Capacity,Max Torque, Engine , Fuel type, Kilometer, Max Power, Transmission,Date)

# %% [markdown]
# Splitting the training data into features and target variables and excluding irrelevant columns like Owner and Color, as well as Seating Capacity and Seller Type, which don't contribute to the model without feature selection.

# %%
X = data.drop(['Owner','Seating Capacity','Drivetrain','Color','Seller Type','Location','Price'],axis=1)
y = data['Price']

# %% [markdown]
# Importing the mutual info classifier from the sklearn library, applying it to the features and target, and plotting the mutual information values between features and the target on a graph for improved readability.

# %%
from sklearn.feature_selection import mutual_info_regression
from sklearn.preprocessing import LabelEncoder


label_encoder = LabelEncoder()
x_encoded = X.copy()  # Create a copy of the features to preserve the original data
for col in X.columns:
    if X[col].dtype == 'object':
        x_encoded[col] = label_encoder.fit_transform(X[col])

# Calculate mutual information scores
mutual_info_scores = mutual_info_regression(x_encoded, y, random_state=1)

# Sort indices based on mutual information scores
top_indices = np.argsort(mutual_info_scores)[::-1]

# Plotting the features by mutual information scores
plt.figure(figsize=(8, 6))
plt.bar(x.columns[top_indices], mutual_info_scores[top_indices], color='skyblue')
plt.xlabel('Features')
plt.ylabel('Mutual Information Score')
plt.title('Features by Mutual Information')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# - - -

# %% [markdown]
# # your code goes here

# %% [markdown]
# **Linear Regression**

# %%
X = data.drop(['Price'],axis=1)
y = data['Price']

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Splitting the data into training and testing data
regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.8556612694235798

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Price', 'Year', 'Kilometer', 'Fuel Type',
#        'Transmission', 'Location', 'Color', 'Owner', 'Seller Type', 'Engine',
#        'Max Power', 'Max Torque', 'Drivetrain', 'Length', 'Width', 'Height',
#        'Seating Capacity', 'Fuel Tank Capacity'],
#       dtype='object')

# %% [markdown]
# **Scaling**

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler()
data['Make'] = standard_scaler.fit_transform(np.array(data['Make']).reshape(-1,1))
data['Model'] = standard_scaler.fit_transform(np.array(data['Model']).reshape(-1,1))
data['Year']=standard_scaler.fit_transform(np.array(data['Year']).reshape(-1,1))
data['Kilometer']=standard_scaler.fit_transform(np.array(data['Kilometer']).reshape(-1,1))
data['Fuel Type']=standard_scaler.fit_transform(np.array(data['Fuel Type']).reshape(-1,1))
data['Transmission']=standard_scaler.fit_transform(np.array(data['Transmission']).reshape(-1,1))
data['Location']=standard_scaler.fit_transform(np.array(data['Location']).reshape(-1,1))
data['Color']=standard_scaler.fit_transform(np.array(data['Color']).reshape(-1,1))
data['Owner']=standard_scaler.fit_transform(np.array(data['Owner']).reshape(-1,1))
data['Seller Type']=standard_scaler.fit_transform(np.array(data['Seller Type']).reshape(-1,1))
data['Engine']=standard_scaler.fit_transform(np.array(data['Engine']).reshape(-1,1))
data['Max Power']=standard_scaler.fit_transform(np.array(data['Max Power']).reshape(-1,1))
data['Max Torque']=standard_scaler.fit_transform(np.array(data['Max Torque']).reshape(-1,1))
data['Drivetrain']=standard_scaler.fit_transform(np.array(data['Drivetrain']).reshape(-1,1))
data['Length']=standard_scaler.fit_transform(np.array(data['Length']).reshape(-1,1))
data['Width']=standard_scaler.fit_transform(np.array(data['Width']).reshape(-1,1))
data['Height']=standard_scaler.fit_transform(np.array(data['Height']).reshape(-1,1))
data['Seating Capacity']=standard_scaler.fit_transform(np.array(data['Seating Capacity']).reshape(-1,1))
data['Fuel Tank Capacity']=standard_scaler.fit_transform(np.array(data['Fuel Tank Capacity']).reshape(-1,1))
data.head()
# Out:
#        Make     Model      Price      Year  Kilometer  Fuel Type  \
# 0 -1.531234 -1.708542  15.274126  1.081589  -1.544000   -0.87424
# 1 -1.531234 -1.708542  15.226498  1.081589  -1.459553   -0.87424
# 2 -1.531234 -1.705297  13.592368 -1.347304   0.740841   -0.87424
# 3 -1.531234 -1.702052  13.997833 -1.347304   1.621129   -0.87424
# 4 -1.531234 -1.698807  15.330638  1.385200  -0.790897   -0.87424
#
#    Transmission  Location     Color     Owner  Seller Type    Engine  \
# 0     -1.106138  1.233551 -1.573698 -0.502638     0.170702  0.197201
# 1     -1.106138 -0.270442 -1.573698 -0.502638    -5.075196  0.197201
# 2     -1.106138  0.663071  0.843562  1.657970     0.170702 -1.111052
# 3     -1.106138 -1.618850  0.843562 -0.502638     0.170702 -1.111052
# 4     -1.106138 -0.892784  0.843562 -0.502638     0.170702  0.197201
#
#    Max Power  Max Torque  Drivetrain    Length     Width    Height  \
# 0  -0.357642    0.789001   -0.045850  0.563517  0.278227 -1.306070
# ...

# %%
X = data.drop(['Price'],axis=1)
y = data['Price']

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Splitting the data into training and testing data
regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.8765761240770191

# %% [markdown]
# **Linear Regression From Scratch**

# %%
# Importing libraries

import numpy as np

import pandas as pd

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# Linear Regression

class LinearRegression() :

	def __init__( self, learning_rate, iterations ) :

		self.learning_rate = learning_rate

		self.iterations = iterations

	# Function for model training

	def fit( self, X, Y ) :

		# no_of_training_examples, no_of_features

		self.m, self.n = X.shape

		# weight initialization

		self.W = np.zeros( self.n )

		self.b = 0

		self.X = X

		self.Y = Y


		# gradient descent learning

		for i in range( self.iterations ) :

			self.update_weights()

		return self

	# Helper function to update weights in gradient descent

	def update_weights( self ) :

		Y_pred = self.predict( self.X )

		# calculate gradients

		dW = - ( 2 * ( self.X.T ).dot( self.Y - Y_pred ) ) / self.m

		db = - 2 * np.sum( self.Y - Y_pred ) / self.m

		# update weights

		self.W = self.W - self.learning_rate * dW

		self.b = self.b - self.learning_rate * db

		return self

	# Hypothetical function h( x )

	def predict( self, X ) :

		return X.dot( self.W ) + self.b


# driver code

def main() :



	# Splitting dataset into train and test set

	X_train, X_test, y_train, y_test = train_test_split(
	X, y, test_size = 1/3, random_state = 0 )

	# Model training

	model = LinearRegression( iterations = 1000, learning_rate = 0.01 )

	model.fit( X_train, y_train )

	# Prediction on test set

	y_pred = model.predict( X_test )

	print( "Predicted values ", np.round( y_pred[:3], 2 ) )

	print( "Real values	 ", y_test[:3] )

	print( "Trained W	 ", round( model.W[0], 2 ) )

	print( "Trained b	 ", round( model.b, 2 ) )



if __name__ == "__main__" :

	main()
# Out:
# Predicted values  1826    13.60
# 1505    13.45
# 1994    14.68
# dtype: float64
# Real values	  1826    13.217675
# 1505    13.161586
# 1994    14.557448
# Name: Price, dtype: float64
# Trained W	  -0.02
# Trained b	  13.82
# <ipython-input-326-e722b4e963ee>:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print( "Trained W	 ", round( model.W[0], 2 ) )

# %%
print(regr.score(X_test, y_test))
# Out:
# 0.8765761240770191

# %%
# Splitting dataset into train and test set

X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 1/3, random_state = 0 )

# Model training

model = LinearRegression( iterations = 1000, learning_rate = 0.01 )

model.fit( X_train, y_train )

# Prediction on test set

y_pred = model.predict( X_test )

print( "Predicted values ", np.round( y_pred[:3], 2 ) )

print( "Real values	 ", y_test[:3] )

print( "Trained W	 ", round( model.W[0], 2 ) )

print( "Trained b	 ", round( model.b, 2 ) )
# Out:
# Predicted values  1826    13.60
# 1505    13.45
# 1994    14.68
# dtype: float64
# Real values	  1826    13.217675
# 1505    13.161586
# 1994    14.557448
# Name: Price, dtype: float64
# Trained W	  -0.02
# Trained b	  13.82
# <ipython-input-333-88e176fca6e1>:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print( "Trained W	 ", round( model.W[0], 2 ) )

# %%
import sklearn.metrics as sm
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, y_pred), 2))
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred), 2))
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred), 2))
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred), 2))
print("R2 score =", round(sm.r2_score(y_test, y_pred), 2))
# Out:
# Mean absolute error = 0.27
# Mean squared error = 0.13
# Median absolute error = 0.2
# Explain variance score = 0.86
# R2 score = 0.86

# %%
import joblib

filename = "car_price_prediction_model"
joblib.dump = (model, filename)

# %%
import joblib

filename = "car_price_prediction_model2"
joblib.dump = (regr, filename)

# %% [markdown]
# # Credits:
#
# This notebook is created by [Connect X](https://www.linkedin.com/company/connectx23/)
# AI team.
#
# -------------------------------------------
#
# **Directed by:**
#
# AI team director [Ammar Thabet](https://www.linkedin.com/in/ammar-thabett/)
